# %% [markdown]
# # How to Read

# %% [markdown]
# Resources:
#
# * [Farnham Street's summary of How to Read a Book](https://fs.blog/how-to-read-a-book/)

# %% [markdown]
# I have a problem. I feel like I have to memorize non-fiction books, which causes me to either read slow or avoid reading altogether out of fear of what I am missing.
#
# My guess is this stems from seeing 'photographic memory' folks read something once and be able to recite it verbatim. I was always *so jealous* of someone who appeared like they could do this.
#
# To (over)compensate for what I feel is a below average memory, I over highlight, take too many notes, and focus on memorizing the smallest of details. This is if I even have the *energy to work this hard* at reading - a lot of the time I will just *avoid reading altogether* out of fear of forgetting details. This is quite sad.
#
# I **need a system**; a happy compromise between a thirst for information and the reality of my brain's limitations. My goal is to read non-fiction as leisure - instead of TV, I want to read. But I cannot do this with these memorization shackles tied to the activity.
#
# To add complexity, I find if I don't highlight and take note(s) then I can often *drift off* while reading. I almost need an efficient way to actively synthesize while reading. Objectively, a reading system I could stick to would be something like starring key points, then highlighting a max of like 3 sentences per chapter, and/or writing a max of 3 sentences in the margin? Then at the end having 1-page summary of the whole book, focusing on concepts instead of facts?

# %% [markdown]
# ## Solution for How to Read (TLDR)

# %% [markdown]
# ### The Filter Framework
#
# **Mindset:** You are a filter, not a hard drive. Catch what changes how you think, decide, or act. Let everything else pass through. Facts are searchable. Frameworks are what you keep.
#
# ---
#
# #### Setup
#
# One sheet of paper, folded into the book/printed article as a bookmark.
#
# **Front:**
# ```
# Q: [Anchor question]
#
# CHECKPOINTS:
# 1 –
# 2 –
# 3 –
# ...
# ```
#
# **Back:**
# ```
# KEY IDEAS / COMPONENTS:
# 1.
# 2.
# 3.
# 4.
# 5.
#
# TRADEOFFS / LIMITATIONS:
#
#
# ACTIONS / WHEN TO USE:
# •
# •
# ```
#
# ---
#
# #### Anchor Questions by Type
#
# Every author writes with a purpose. They're trying to convince you of something, explain how something works, or share what they discovered. Your anchor question cuts straight to that purpose—it's how you avoid drowning in details and stay locked onto what the author actually wants you to walk away with.
#
# | Material type | Author's purpose | Anchor question |
# |---|---|---|
# | Non-fiction book | Convince you of a thesis | *"What is this book arguing, and why should I believe it?"* |
# | Technical article/docs | Teach you how something works | *"What problem does this solve and how?"* |
# | Research paper | Report a finding | *"What's the claim, what method tested it, and what did they find?"* |
# | Opinion/essay | Shift your perspective | *"What does the author want me to see differently?"* |
# | Biography/history | Illuminate through narrative | *"What's the through-line, and what does it reveal?"* |
#
# Before you read a word, ask: *"What is this author trying to do to my brain?"* Your anchor question makes that explicit—and everything you capture should connect back to it.
#
# ---
#
# #### The Flow
#
# **1. Scout (5-15 min)**
#
# | Non-fiction | Technical |
# |---|---|
# | Title, back cover, TOC, chapter openings/endings | Headings, diagrams, code blocks, intro/conclusion |
#
# Write your anchor question at the top of your paper.
#
# **2. Read**
#
# Read at a comfortable pace. Stars go in the margin.
#
# **Max 3 stars per chapter/section.** To add a 4th, remove one.
#
# | Star this | Not this |
# |---|---|
# | Core claims or mechanisms | Examples, anecdotes, evidence |
# | Reframes that shift your view | "That's interesting" moments |
# | Actionable takeaways | Repetition of earlier ideas |
# | Components and how they connect | Implementation details you can look up |
# | Tradeoffs and failure modes | Syntax, boilerplate, code snippets |
#
# **3. Checkpoint (2 min, after each chapter/section)**
#
# Pull out your paper. Write one sentence.
#
# | Non-fiction | Technical |
# |---|---|
# | *"This chapter argued that [X] because [Y]."* | *"[Component/concept] does [X] by [Y]."* |
#
# **Y = the reasoning:**
# - Mechanism ("because it works by...")
# - Evidence ("because studies show...")
# - Logic ("because if A, then B...")
# - Reframe ("because we've been thinking about it wrong...")
#
# **4. Distill (5-10 min, after finishing)**
#
# Review checkpoints. Circle the 3-5 best. Fill in the back:
#
# **For non-fiction:**
# ```
# ANSWER: [1-2 sentences—author's response to your question]
#
# KEY IDEAS:
# 1.
# 2.
# 3.
#
# ACTIONS: [What will you do differently?]
# ```
#
# **For technical:**
# ```
# PROBLEM: [What does this solve?]
#
# MECHANISM: [How does it work, in one sentence?]
#
# COMPONENTS:
# 1.
# 2.
# 3.
#
# TRADEOFFS: [Where does it fail? What are the costs?]
#
# WHEN TO USE: [What situations call for this?]
# ```
#
# Photo the sheet. File it. Done.
#
# ---
#
# #### Optional: Spaced Repetition (≤10 cards, skeleton only)
#
# | Card type | Non-fiction example | Technical example |
# |---|---|---|
# | Core question/answer | "What's the main argument of [book]?" | "What problem does [X] solve?" |
# | Key idea / component | "What does [concept] mean?" | "What does [component] do?" |
# | Application | "When would I use this insight?" | "When would I use [X] over [Y]?" |
# | Tradeoff/failure | "Where does this argument break down?" | "When does [X] fail?" |
#
# **No fact cards. No trivia. No implementation details.**
#
# If you want more than 10 cards, stop. That's the old pattern.
#
# ---
#
# #### The Shift
#
# | Old | New |
# |---|---|
# | Everything is important | Most is forgettable |
# | I must memorize | I must filter |
# | My brain is storage | My one-page summary is storage |
# | Forgetting = failure | Forgetting = working as intended |
# | I want to be an encyclopedia | I want to be a thinker |
# | I memorize how it works | I know *when and why* to use it |
#
# ---
#
# A book succeeds if you think, decide, or act even 1% differently.
#
# An article succeeds if you know *when to reach for it* and *what tradeoffs to expect*.
#
# **Store the skeleton. Let the flesh be searchable.**

# %% [markdown]
# ## Background

# %% [markdown]
# Read the resources above and devise a clear, structured plan for how I should read quickly while maximizing what I can extract from a book. Consider what I wrote above about my own bad habits and ideas for a system. I need something clear and simple - a framework for how to read.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Based on your notes and the resources, here's a framework designed specifically for your situation—someone who wants reading to be *leisure*, not labor, while still extracting value.
#
# ---
#
# **The 3-Pass Framework**
#
# **Pass 1: Scout (10-15 min)**
# Before reading anything properly, skim: title, back cover, table of contents, first/last paragraphs of chapters. Ask yourself: *"What question is this book trying to answer?"* Write that question at the top of a blank page. This anchors everything.
#
# **Pass 2: Read (with constraints)**
# Read at a comfortable pace. Your only job is to mark things that surprise you or that you'd tell a friend about. Use these hard limits:
#
# - ⭐ **Max 3 stars per chapter** – for genuinely important ideas
# - **Max 1 margin note per chapter** – one sentence in your own words
# - No highlighting sentences (too passive, feeds the completionist urge)
#
# The constraint *is* the system. If you're tempted to star a 4th thing, you must unstar something else. This forces your brain to rank, not hoard.
#
# **Pass 3: Distill (5-10 min after finishing)**
# One page, structured like this:
#
# 1. **The question** (from Pass 1)
# 2. **The answer** (1-2 sentences—how does the author answer it?)
# 3. **3-5 key ideas** (pulled from your stars)
# 4. **1-2 actions** (what will you do differently because of this book?)
#
# If it's not on this page, you have *explicit permission to forget it*. The book still exists—you can look things up.
#
# ---
#
# **Why this works for you specifically:**
#
# - **Drifting off**: The starring constraint keeps you engaged—you're constantly evaluating "is this top-3 material?"
# - **Over-highlighting**: Hard caps make this impossible. You literally can't.
# - **Fear of forgetting**: The one-page distillation is your external memory. You're not relying on your brain; you're relying on your system.
# - **Reading as leisure**: Most of your reading time is just... reading. The work is front-loaded (scout) and back-loaded (distill), not constant.
#
# ---
#
# **The mindset shift:**
#
# Your goal isn't to *store* the book. It's to *change* slightly because of it. If you finish a book and think/decide/act even 1% differently, the book worked. Everything else is reference material.
#
# Try this on your next book and tell me how it goes.

# %% [markdown]
# ok but my short-term memory is the problem. I will read a chapter and then the next day, most of the info is gone from my brain. Having the summary at the end of the book, which may be weeks since I started, I am guaranteed to forget earlier chapters - even the major points. I need something more intermediate but that also isnt draining. This feels like an impossible problem?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Not impossible—you just need a **running capture** instead of an end-of-book dump. Here's the fix:
#
# ---
#
# **Add: The Chapter Checkpoint (2 min max)**
#
# After finishing each chapter (or reading session), immediately write **one sentence**:
#
# > "This chapter argued that [X] because [Y]."
#
# That's it. One sentence. On the same page where you'll eventually write your final summary. You're building the summary *as you go*, not reconstructing it from a foggy memory weeks later.
#
# Your page now looks like this as you read:
#
# ```
# THE QUESTION: Why do habits stick?
#
# CHAPTER CHECKPOINTS:
# Ch 1 – Habits are cue-routine-reward loops, not willpower.
# Ch 2 – The cue is often invisible; you have to surface it.
# Ch 3 – Keystone habits cascade into other changes.
# ...
#
# [Final distillation goes here when done]
# ```
#
# When you finish the book, your summary is 80% written. You just review your checkpoints, circle the 3-5 that matter most, and add your action items.
#
# ---
#
# **Why this works:**
#
# - **Timing**: You write while the chapter is fresh—no reconstruction needed
# - **Effort**: One sentence is so low-friction it doesn't break the leisure vibe
# - **Cumulative**: Each checkpoint is a breadcrumb back to that chapter's core idea
# - **Visible progress**: Watching the list grow feels good, not draining
#
# ---
#
# **The updated flow:**
#
# 1. **Scout** (10-15 min) → write the question
# 2. **Read** (stars + 1 margin note per chapter)
# 3. **Checkpoint** (1 sentence, 2 min) → after each chapter
# 4. **Distill** (5 min) → review checkpoints, pick the best 3-5, add actions
#
# Does that feel sustainable?

# %% [markdown]
# and what is the focus of stars in the read portion of the flow? and how is this different to underlining?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# **What to star:**
#
# Star things that make you go *"oh, that's the point"* or *"I'd mention this to someone"*. Specifically:
#
# - **Core claims** – the argument itself, not the evidence for it
# - **Surprising reframes** – when the author shifts how you see something
# - **Actionable insight** – something you could actually *do*
#
# Don't star: examples, stories, statistics, repetitions of the same idea, or "that's interesting" moments that don't change anything.
#
# The filter is: *"Would this make it into my 3-5 key ideas?"* If not, no star.
#
# ---
#
# **How it differs from underlining/highlighting:**
#
# | | Underlining/Highlighting | Starring |
# |---|---|---|
# | **Granularity** | Sentences, phrases | Whole ideas (a paragraph, a page) |
# | **Quantity** | Tends to sprawl | Hard-capped (3 per chapter) |
# | **Purpose** | "This is good" | "This is *top-tier*" |
# | **Cognitive mode** | Passive marking | Active ranking |
#
# Underlining says *"I noticed this."*
# Starring says *"If I only remember 3 things from this chapter, this is one of them."*
#
# The constraint forces ranking, which forces understanding. You can't decide what's most important without actually processing what you read—which is exactly what keeps you from drifting off.

# %% [markdown]
# Okay, so rewrite your flow in a catchy way that's easy to understand. And remember, knowing that we have a limit on stars as well, I think you forgot to mention that in your flow overview. I like that you define stars as something you tell someone about. I want a little bit more... info there about what defines a star. And... Also in the checkpoint. That because Y, what are some examples, are the constructive criteria for what I should include as Y. Finally, including your summary, a mindset shift where we have to move away from memorizing everything and everything is interesting and important to some higher level mindset.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# ---
#
# ## The Scout → Read → Checkpoint → Distill Framework
#
# **Mindset first:** You are not a hard drive. You're a *filter*. Your job isn't to store the book—it's to let most of it pass through and catch only what changes how you think, decide, or act. Everything else is reference material that still exists on the shelf.
#
# ---
#
# ### 1. Scout (10-15 min)
#
# Before reading, skim: title, back cover, table of contents, chapter openings/endings. Then write one question at the top of a blank page:
#
# > *"What is this book trying to answer?"*
#
# This is your anchor. Everything you capture should relate back to it.
#
# ---
#
# ### 2. Read (with constraints)
#
# Read at a relaxed pace. Your only task is to **star what you'd tell a friend about**.
#
# **Max 3 stars per chapter.** If you want to star a 4th thing, you must unstar something else.
#
# **What earns a star:**
# - A core claim (the *point*, not the proof)
# - A reframe that *shifts how you see something*
# - An actionable takeaway you could actually use
# - The answer (or part of the answer) to your anchor question
#
# **What doesn't earn a star:**
# - Examples, anecdotes, or evidence (these support stars—they aren't stars)
# - "That's interesting" moments that don't change anything
# - Repetition of an idea you already starred
#
# One margin note per chapter is optional—only if something needs rephrasing in your own words.
#
# ---
#
# ### 3. Checkpoint (2 min, after each chapter)
#
# Immediately write one sentence on your running page:
#
# > *"This chapter argued that [X] because [Y]."*
#
# **X = the claim.** What did the author want you to believe or understand?
#
# **Y = the reasoning.** Why should you believe it? This could be:
# - A mechanism ("because habits run on cue-routine-reward loops")
# - Evidence type ("because studies show X correlates with Y")
# - A logical move ("because if A is true, then B must follow")
# - A reframe ("because we've been thinking about it wrong—it's not willpower, it's environment")
#
# If you can't fill in Y, you didn't understand the chapter. Skim back to your stars.
#
# ---
#
# ### 4. Distill (5-10 min, after finishing)
#
# Review your checkpoints. Circle the 3-5 that matter most. Then complete your page:
#
# 1. **The question** (from Scout)
# 2. **The answer** (1-2 sentences—the author's response)
# 3. **3-5 key ideas** (from your best checkpoints)
# 4. **1-2 actions** (what you'll do differently)
#
# If it's not on this page, you have permission to forget it.
#
# ---
#
# ### The Shift
#
# | Old mindset | New mindset |
# |---|---|
# | Everything is important | Most things are forgettable |
# | I must remember | I must *filter* |
# | Reading is memorizing | Reading is *changing slightly* |
# | My brain is storage | My one-page summary is storage |
# | Forgetting = failure | Forgetting = working as intended |
#
# A book succeeds if you think, decide, or act even 1% differently afterward. That's it. You're not studying for an exam—you're shaping how you see the world, one filter at a time.

# %% [markdown]
# Okay, so I should have a pen and a single piece of paper that I fold up in the book. Like how does the actual notes work?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, exactly. One piece of paper, folded into the book, serves as your entire note system for that book. Here's how it works:
#
# ---
#
# **The Setup**
#
# Take a single sheet of paper (or an index card if you prefer). Fold it in half or thirds so it fits as a bookmark. This is your **capture sheet**.
#
# **Front side:**
# ```
# Q: [Your anchor question from Scout]
#
# CHECKPOINTS:
# Ch 1 –
# Ch 2 –
# Ch 3 –
# ...
# ```
#
# **Back side (or bottom half):**
# ```
# KEY IDEAS:
# 1.
# 2.
# 3.
# 4.
# 5.
#
# ACTIONS:
# •
# •
# ```
#
# ---
#
# **How it flows in practice**
#
# 1. **Scout** → Write the question at the top
# 2. **Read** → Stars go in the book itself (pencil or a tiny dot in the margin). The paper stays tucked in as your bookmark.
# 3. **Checkpoint** → When you finish a chapter, pull out the paper, write your one sentence, tuck it back in
# 4. **Distill** → When done, flip to the back side, fill in the key ideas (pulled from your best checkpoints) and actions
#
# ---
#
# **Why this works**
#
# - The paper is always *with* the book—no separate notebook to forget
# - Physical constraint (one sheet) reinforces the mental constraint (only capture what matters)
# - When you finish, you have a portable summary you can file, photograph, or transcribe
#
# Some people keep a small box or folder of these sheets, one per book. Your "library" becomes a stack of single pages—each one a compressed version of what actually mattered.

# %% [markdown]
# ok and what about essential facts? like. copernicus discovered heliocentrism in 16th century. this is bedrock knowledge upon which we build other knowledge. how does this fit into the system?
#
# this is dangerous because like i said earlier I find everything interesting...
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# This is the trap. Let's defuse it.
#
# ---
#
# **The distinction: Bedrock vs Trivia**
#
# Not all facts are bedrock. A fact is only bedrock if *other ideas you care about depend on it*. Ask:
#
# > *"Do I need this fact to understand or use the ideas I'm keeping?"*
#
# - "Copernicus proposed heliocentrism" → Probably bedrock if you're building a mental model of scientific revolutions
# - "It was the 16th century" → Maybe useful for sequencing, but do you *need* the date?
# - "He published in 1543" → Almost certainly trivia unless you're writing a history paper
#
# The test: if you forgot the fact, would your key ideas collapse? If not, it's trivia dressed up as importance.
#
# ---
#
# **How facts fit in the system**
#
# Facts don't get stars. Facts *support* stars.
#
# If a fact is genuinely essential to a starred idea, it gets absorbed into your checkpoint sentence or key idea. For example:
#
# > "This chapter argued that the Scientific Revolution required heliocentrism (Copernicus) to displace church authority over nature."
#
# The fact is embedded in the idea. You're not memorizing "Copernicus, 1543, heliocentric model"—you're remembering *why it mattered*.
#
# If the fact doesn't fit into a checkpoint or key idea, you probably don't need it.
#
# ---
#
# **The "everything is interesting" trap**
#
# Yes, Copernicus is interesting. So is the etymology of the word "planet." So is the name of his university. Interesting ≠ essential.
#
# Try this filter:
#
# | Question | If yes... |
# |---|---|
# | Does this fact explain *why* something happened? | Maybe keep |
# | Does this fact change what I'd *do*? | Probably keep |
# | Is this fact just *cool to know*? | Let it go |
#
# You can always look up the date later. You can't look up the insight that changed your thinking—that has to live in your summary.
#
# ---
#
# **The liberating reframe**
#
# Facts are cheap. They're on Wikipedia. Your job isn't to be an encyclopedia—it's to build *frameworks* that let you make sense of new facts when you encounter them.
#
# Store the skeleton. Let the flesh be searchable.

# %% [markdown]
# Okay, so I think this is actually the crux of the idea of my problem. I *want* to be an encyclopedia and be amazing at trivia games. In reality, I- that is no strength of mine, so I need to let this go.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes. That's the root.
#
# You've been optimizing for a game you're not built to win—and it's been costing you the game you *could* win.
#
# ---
#
# **The tradeoff you've been making:**
#
# | Chasing encyclopedic recall | What it costs |
# |---|---|
# | Exhausting reading sessions | Reading as leisure |
# | Over-highlighting everything | Knowing what actually matters |
# | Avoiding books entirely | Exposure to new ideas |
# | Anxiety about forgetting | Enjoyment |
#
# You've been paying a huge tax for a reward you rarely collect.
#
# ---
#
# **What you *can* be:**
#
# Not the person who remembers that Copernicus published in 1543.
#
# The person who, when someone mentions Copernicus, says: *"Right—the shift from geocentric to heliocentric wasn't just astronomy, it was about who gets to define reality: the church or observation."*
#
# That's not trivia. That's *synthesis*. That's having a framework that makes new information land somewhere meaningful.
#
# Trivia players retrieve facts.
# Thinkers retrieve *lenses*.
#
# ---
#
# **The grief is real**
#
# Letting go of the encyclopedia fantasy might feel like admitting defeat. It's not. It's choosing to be a different kind of reader—one who trades breadth of recall for depth of understanding.
#
# You'll lose at pub trivia. You'll win at *thinking clearly about things that matter to you*.
#
# That's a good trade.

# %% [markdown]
# But what about this idea, and how does this contrast with the theory that you can actually become a trivia person if you use space repetition? Like, how does this fit into this whole framework, or am I now trying to solve for a different problem?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# You're now solving for a different problem.
#
# ---
#
# **Two separate games:**
#
# | Game A: Read for insight | Game B: Build trivia recall |
# |---|---|
# | Goal: Change how you think | Goal: Retrieve facts on demand |
# | Method: Filter ruthlessly | Method: Encode broadly |
# | Tool: One-page summary | Tool: Spaced repetition |
# | Effort: Front-loaded (while reading) | Effort: Ongoing (daily reviews) |
#
# Spaced repetition *does* work for trivia. You absolutely *can* become that person—if you're willing to pay the maintenance cost. Every fact you add is a card you review forever. It's a lifestyle, not a technique.
#
# ---
#
# **The honest question:**
#
# > *"Do I want to be a trivia person badly enough to do daily reviews indefinitely?"*
#
# If yes: Build a separate spaced repetition habit. Add facts deliberately. Accept the ongoing cost.
#
# If no (or "maybe someday"): Stop letting that fantasy pollute your reading. The framework we built is for Game A. It works *because* it ignores Game B.
#
# ---
#
# **The danger of mixing them:**
#
# If you try to do both at once, you'll:
# - Over-capture facts while reading (back to old habits)
# - Create too many cards (review debt piles up)
# - Feel guilty when you skip reviews
# - Eventually abandon both
#
# ---
#
# **My suggestion:**
#
# Separate them completely. For now, commit to Game A only. Read for insight using the Scout → Read → Checkpoint → Distill system. No spaced repetition.
#
# If six months from now you're reading consistently, enjoying it, and still want to build trivia recall—*then* start a modest spaced repetition practice as a separate hobby. Add 5 cards a day max. Treat it like going to the gym: a different activity with different rules.
#
# But don't let the trivia fantasy hijack your reading life. You've already seen where that leads.

# %% [markdown]
# Fine, but does space repetition play a role in this system? I guess I can always take a picture of the notes and digitize them and have space repetition help ensure these details arent forgotten?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes, spaced repetition can play a **limited, structural role** in this system—but only if you use it correctly.
#
# ---
#
# **The rule: SR for the skeleton only**
#
# After you finish your one-page distillation, you can optionally create **≤10 cards per book**:
#
# - 1-2 cards on the anchor question/answer
# - 3-5 cards on your key ideas
# - 2-3 cards on application ("When would I use X? Give an example.")
#
# That's it. You're encoding the *framework*, not the facts. You're making sure the ideas stick, not that you can recite details.
#
# ---
#
# **Example cards from a hypothetical book:**
#
# **Bad cards (trivia):**
# - Q: When did Copernicus publish? A: 1543
# - Q: What are the three parts of a habit loop? A: Cue, routine, reward
#
# **Good cards (structural):**
# - Q: What's the core argument of *Atomic Habits*? A: Habits compound—1% changes create exponential results over time
# - Q: When I'm trying to build a new habit, what should I focus on first? A: Making the cue obvious (environment design, not willpower)
#
# The good cards test whether you *understood* and can *use* the idea, not whether you memorized it.
#
# ---
#
# **The workflow:**
#
# 1. Read book using Scout → Read → Checkpoint → Distill
# 2. Take a photo of your one-page summary
# 3. (Optional) Create ≤10 SR cards from that summary
# 4. File the physical paper, move on
#
# The summary is your external memory. The SR cards are just insurance that you don't lose the *structure* over time.
#
# ---
#
# **The critical constraint:**
#
# If you find yourself wanting to make 30 cards, or cards about specific facts/examples—**stop**. That's the old pattern creeping back in. The 10-card limit is not negotiable. It forces you to ask: *"What's the absolute core here?"*
#
# This keeps SR as a **servant** of the system, not the master.
#
# Does that feel like the right amount of SR involvement?

# %% [markdown]
# Okay, fine. Now that we've introduced this final concept of space repetition, give me the new full system in a quick reference guide.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# ---
#
# ## The Filter Framework: A Quick Reference Guide
#
# **Mindset:** You are a filter, not a hard drive. Your job is to catch what changes how you think, decide, or act—and let everything else pass through. Facts are cheap and searchable. Frameworks are what you keep.
#
# ---
#
# ### Setup
#
# One sheet of paper, folded into the book as your bookmark.
#
# **Front:**
# ```
# Q: [Anchor question]
#
# CHECKPOINTS:
# Ch 1 –
# Ch 2 –
# Ch 3 –
# ...
# ```
#
# **Back:**
# ```
# KEY IDEAS:
# 1.
# 2.
# 3.
# 4.
# 5.
#
# ACTIONS:
# •
# •
# ```
#
# ---
#
# ### The Flow
#
# **1. Scout (10-15 min)**
# Skim: title, back cover, table of contents, chapter openings/endings. Write one question at the top of your paper: *"What is this book trying to answer?"*
#
# **2. Read**
# Read at a relaxed pace. Stars go in the book margins.
#
# **Max 3 stars per chapter.** To add a 4th, you must remove one.
#
# | Star this | Not this |
# |---|---|
# | Core claims (the *point*) | Examples, stories, evidence |
# | Reframes that shift your view | "That's interesting" moments |
# | Actionable takeaways | Repetition of an earlier idea |
# | Answers to your anchor question | Facts you could look up |
#
# **3. Checkpoint (2 min, after each chapter)**
# Pull out your paper. Write one sentence:
#
# > *"This chapter argued that [X] because [Y]."*
#
# - **X** = the claim
# - **Y** = the reasoning (mechanism, evidence, logic, or reframe)
#
# Tuck paper back in. Keep reading.
#
# **4. Distill (5-10 min, after finishing)**
# Flip to the back. Review your checkpoints. Circle the 3-5 best. Fill in:
#
# - **The answer** (1-2 sentences—how the author answers your question)
# - **3-5 key ideas** (from your best checkpoints)
# - **1-2 actions** (what you'll do differently)
#
# Photo the sheet. File it. Done.
#
# ---
#
# ### Optional: Spaced Repetition (skeleton only)
#
# After distilling, create **≤10 cards total**:
#
# - 1-2 on the anchor question/answer
# - 3-5 on key ideas
# - 2-3 on application ("When would I use X?")
#
# **No fact cards. No trivia. Structure only.**
#
# If you want to make more than 10 cards, that's the old pattern. Stop.
#
# ---
#
# ### The Shift
#
# | Old | New |
# |---|---|
# | Everything is important | Most is forgettable |
# | I must memorize | I must filter |
# | My brain is storage | My one-page summary is storage |
# | Forgetting = failure | Forgetting = working as intended |
# | I want to be an encyclopedia | I want to be a thinker |
#
# ---
#
# A book succeeds if you think, decide, or act even 1% differently afterward.
#
# Store the skeleton. Let the flesh be searchable.

# %% [markdown]
# Does this also apply to more technical articles? Like if I'm looking at what RAG is for machine learning, does this whole philosophy still apply?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Good question. The philosophy applies, but the *implementation* shifts.
#
# ---
#
# **What stays the same:**
#
# - You're still a filter, not a hard drive
# - You still capture structure over details
# - You still ask: *"What changes how I think or what I can do?"*
#
# ---
#
# **What's different with technical material:**
#
# | Non-fiction books | Technical articles/docs |
# |---|---|
# | Arguing a thesis | Explaining how something works |
# | Anchor question: "What's the argument?" | Anchor question: "What problem does this solve and how?" |
# | Key ideas = claims | Key ideas = components, patterns, tradeoffs |
# | Actions = behavior changes | Actions = "When would I use this? How would I implement it?" |
# | Read cover to cover | Read selectively, often jump around |
#
# ---
#
# **Adapted flow for technical articles:**
#
# **1. Scout (5 min)**
# Skim headings, diagrams, code blocks. Write:
#
# > *"What problem does [X] solve, and what's the core mechanism?"*
#
# For RAG: *"What problem does RAG solve, and how does it work?"*
#
# **2. Read (selectively)**
# You don't need to read every section. Focus on:
# - The "why" (what problem, what tradeoff)
# - The architecture/flow (how components connect)
# - The gotchas (where it fails, when not to use it)
#
# Star the same way: max 3 per major section.
#
# **3. Checkpoint (as you go)**
# One sentence per section, but more mechanical:
#
# > *"[Component] does [X] by [Y]."*
#
# For RAG:
# - "Retrieval fetches relevant docs from a vector store based on query similarity."
# - "Augmentation injects retrieved context into the prompt."
# - "Generation produces output grounded in retrieved evidence."
#
# **4. Distill**
# Your summary looks slightly different:
#
# ```
# PROBLEM: LLMs hallucinate and lack access to private/recent data.
#
# MECHANISM: Retrieve relevant docs → inject into prompt → generate grounded response.
#
# COMPONENTS:
# - Embedding model (encodes query + docs)
# - Vector store (retrieves similar chunks)
# - LLM (generates with augmented context)
#
# TRADEOFFS:
# - Adds latency
# - Quality depends on chunking + retrieval
# - Doesn't "know" the docs, just sees them
#
# WHEN TO USE:
# - QA over private docs
# - Grounding LLM in current info
# ```
#
# ---
#
# **SR for technical material:**
#
# Still ≤10 cards, but more like:
#
# - Q: What problem does RAG solve? A: LLMs hallucinating / lacking access to private or recent data
# - Q: What are the three stages of RAG? A: Retrieve → Augment → Generate
# - Q: When would RAG fail? A: Poor chunking, bad embeddings, retrieval misses relevant docs
#
# ---
#
# **The core principle remains:**
#
# You're learning *when and why* to use something, not memorizing implementation details. Those live in documentation you can search. Your job is to know *"RAG is the tool for grounding LLMs in external knowledge"*—not to recite the code.

# %% [markdown]
# Okay, now update your summary with the technical elements as well to have one comprehensive workflow that is access quick reference card in order to read properly.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# ---
#
# ## The Filter Framework: Quick Reference Guide
#
# **Mindset:** You are a filter, not a hard drive. Catch what changes how you think, decide, or act. Let everything else pass through. Facts are searchable. Frameworks are what you keep.
#
# ---
#
# ### Setup
#
# One sheet of paper, folded into the book/printed article as a bookmark.
#
# **Front:**
# ```
# Q: [Anchor question]
#
# CHECKPOINTS:
# 1 –
# 2 –
# 3 –
# ...
# ```
#
# **Back:**
# ```
# KEY IDEAS / COMPONENTS:
# 1.
# 2.
# 3.
# 4.
# 5.
#
# TRADEOFFS / LIMITATIONS:
#
#
# ACTIONS / WHEN TO USE:
# •
# •
# ```
#
# ---
#
# ### Anchor Questions by Type
#
# | Material type | Anchor question |
# |---|---|
# | Non-fiction book | *"What is this book arguing?"* |
# | Technical article/docs | *"What problem does this solve and how?"* |
# | Research paper | *"What's the claim, method, and finding?"* |
#
# ---
#
# ### The Flow
#
# **1. Scout (5-15 min)**
#
# | Non-fiction | Technical |
# |---|---|
# | Title, back cover, TOC, chapter openings/endings | Headings, diagrams, code blocks, intro/conclusion |
#
# Write your anchor question at the top of your paper.
#
# **2. Read**
#
# Read at a comfortable pace. Stars go in the margin.
#
# **Max 3 stars per chapter/section.** To add a 4th, remove one.
#
# | Star this | Not this |
# |---|---|
# | Core claims or mechanisms | Examples, anecdotes, evidence |
# | Reframes that shift your view | "That's interesting" moments |
# | Actionable takeaways | Repetition of earlier ideas |
# | Components and how they connect | Implementation details you can look up |
# | Tradeoffs and failure modes | Syntax, boilerplate, code snippets |
#
# **3. Checkpoint (2 min, after each chapter/section)**
#
# Pull out your paper. Write one sentence.
#
# | Non-fiction | Technical |
# |---|---|
# | *"This chapter argued that [X] because [Y]."* | *"[Component/concept] does [X] by [Y]."* |
#
# **Y = the reasoning:**
# - Mechanism ("because it works by...")
# - Evidence ("because studies show...")
# - Logic ("because if A, then B...")
# - Reframe ("because we've been thinking about it wrong...")
#
# **4. Distill (5-10 min, after finishing)**
#
# Review checkpoints. Circle the 3-5 best. Fill in the back:
#
# **For non-fiction:**
# ```
# ANSWER: [1-2 sentences—author's response to your question]
#
# KEY IDEAS:
# 1.
# 2.
# 3.
#
# ACTIONS: [What will you do differently?]
# ```
#
# **For technical:**
# ```
# PROBLEM: [What does this solve?]
#
# MECHANISM: [How does it work, in one sentence?]
#
# COMPONENTS:
# 1.
# 2.
# 3.
#
# TRADEOFFS: [Where does it fail? What are the costs?]
#
# WHEN TO USE: [What situations call for this?]
# ```
#
# Photo the sheet. File it. Done.
#
# ---
#
# ### Optional: Spaced Repetition (≤10 cards, skeleton only)
#
# | Card type | Non-fiction example | Technical example |
# |---|---|---|
# | Core question/answer | "What's the main argument of [book]?" | "What problem does [X] solve?" |
# | Key idea / component | "What does [concept] mean?" | "What does [component] do?" |
# | Application | "When would I use this insight?" | "When would I use [X] over [Y]?" |
# | Tradeoff/failure | "Where does this argument break down?" | "When does [X] fail?" |
#
# **No fact cards. No trivia. No implementation details.**
#
# If you want more than 10 cards, stop. That's the old pattern.
#
# ---
#
# ### The Shift
#
# | Old | New |
# |---|---|
# | Everything is important | Most is forgettable |
# | I must memorize | I must filter |
# | My brain is storage | My one-page summary is storage |
# | Forgetting = failure | Forgetting = working as intended |
# | I want to be an encyclopedia | I want to be a thinker |
# | I memorize how it works | I know *when and why* to use it |
#
# ---
#
# A book succeeds if you think, decide, or act even 1% differently.
#
# An article succeeds if you know *when to reach for it* and *what tradeoffs to expect*.
#
# **Store the skeleton. Let the flesh be searchable.**

# %% [markdown]
# rewrite the section: Anchor Questions by Type
#
# i need a touch more contextualizing the fact that every author has a 'purpose' for writing. they are trying to convince you of something, or express an idea
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# ---
#
# ### Anchor Questions by Type
#
# Every author writes with a purpose. They're trying to convince you of something, explain how something works, or share what they discovered. Your anchor question cuts straight to that purpose—it's how you avoid drowning in details and stay locked onto what the author actually wants you to walk away with.
#
# | Material type | Author's purpose | Anchor question |
# |---|---|---|
# | Non-fiction book | Convince you of a thesis | *"What is this book arguing, and why should I believe it?"* |
# | Technical article/docs | Teach you how something works | *"What problem does this solve and how?"* |
# | Research paper | Report a finding | *"What's the claim, what method tested it, and what did they find?"* |
# | Opinion/essay | Shift your perspective | *"What does the author want me to see differently?"* |
# | Biography/history | Illuminate through narrative | *"What's the through-line, and what does it reveal?"* |
#
# Before you read a word, ask: *"What is this author trying to do to my brain?"* Your anchor question makes that explicit—and everything you capture should connect back to it.
