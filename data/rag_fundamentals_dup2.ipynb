# %% [markdown]
# # RAG Fundamentals

# %% [markdown]
# **RAG (Retrieval-Augmented Generation)** retrieves *relevant information from a knowledge base*, which we then pass to an LLM to generate a response. It's like giving the LLM a *cheat sheet* of *just the right reference material* before asking it to answer.

# %% [markdown]
# **RAG for Category Mapping**
#
# Say I want to map a product description against a set of predefined categories from a standardized nomenclature—hundreds of items long. RAG helps by pre-filtering those categories down to just the relevant ones before asking the LLM to pick the best match. This matters because A) it's cheaper, and B) the LLM won't miss the right category when it's not buried in noise. RAG acts as the **smart filter** that gives the LLM a focused shortlist instead of the whole haystack.

# %% [markdown]
# get the list of shopify categories. there is a list on their github
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Found it! [*](https://github.com/Shopify/product-taxonomy "GitHub - Shopify/product-taxonomy: Shopify's standardized product taxonomy.") [*](https://github.com/Shopify/product-taxonomy "GitHub - Shopify/product-taxonomy: Shopify's standardized product taxonomy.") [*](https://github.com/Shopify/product-taxonomy "GitHub - Shopify/product-taxonomy: Shopify's standardized product taxonomy.") Shopify has an open-source standardized product taxonomy on GitHub. It's a global standard with a stable structure available in diverse formats, designed for effortless integration.
#
# The repo is: **https://github.com/Shopify/product-taxonomy**
#
# [*](https://github.com/Shopify/product-taxonomy/releases "Releases · Shopify/product-taxonomy") [*](https://github.com/Shopify/product-taxonomy/releases "Releases · Shopify/product-taxonomy") The latest release is 2025-12, which expanded the taxonomy with 1,000+ new categories and 600+ new attributes.
#
# For your RAG use case, the most useful files are in the `dist/` folder. You'll want the **categories in text or JSON format**. The raw distribution files should be at paths like:
# - `dist/en/categories.txt` — simple text list
# - `dist/en/categories.json` — structured JSON
#
# Want me to fetch one of these files directly so we can see the format?

# %% [markdown]
# get the json one and import it here
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Whoops! An error (E300) occurred while processing your request.
# If this problem persists, please contact us on Discord.
# Please include your dialog url and error code in your message.
